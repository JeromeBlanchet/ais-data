# %%
import sys
import subprocess

GITLAB_USER = "read_aistt"  #For use of members of AIS Task Team, read only access
GITLAB_TOKEN = "J1Kk8tArfyXB6dZvFcWW"
git_package = f"git+https://{GITLAB_USER}:{GITLAB_TOKEN}@code.officialstatistics.org/trade-task-team-phase-1/ais.git"

std_out = subprocess.run([sys.executable, "-m", "pip", "install",git_package], capture_output=True, text=True).stdout
print(std_out)
# Out:
# Collecting git+https://read_aistt:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git
#   Cloning https://read_aistt:****@code.officialstatistics.org/trade-task-team-phase-1/ais.git to /tmp/pip-req-build-93gu5bvq
# Building wheels for collected packages: ais
#   Building wheel for ais (setup.py): started
#   Building wheel for ais (setup.py): finished with status 'done'
#   Created wheel for ais: filename=ais-2.7.4-py3-none-any.whl size=9163 sha256=3e66c9a099f52527678849717b62e968cd2a26adc632424db806d94e43fd1714
#   Stored in directory: /tmp/pip-ephem-wheel-cache-orct7ei2/wheels/6d/8c/5e/19898a2b930f8efa2ef2e6ecc8ef48797422e3ec7e0114b312
# Successfully built ais
# Installing collected packages: ais
# Successfully installed ais-2.7.4

# %%
from ais import functions as af

#still need to register Sedona even with template configuration. need to check why
from sedona.register import SedonaRegistrator
SedonaRegistrator.registerAll(spark)

import pandas as pd
import numpy as np
from datetime import datetime
from IPython.display import display

import h3
import h3.api.numpy_int as h3int
import pyspark.sql.functions as F

import os
import getpass

# %%
# Get clone the repo
try:
    std_out = subprocess.run(["git", "clone", "https://github.com/CSBP-CPSE/ais-data.git"],
                             capture_output=True,
                             text=True)
    print(std_out)
    print(os.listdir())
except:
    print("Cloning repo failed")
# Out:
# CompletedProcess(args=['git', 'clone', 'https://github.com/CSBP-CPSE/ais-data.git'], returncode=0, stdout='', stderr="Cloning into 'ais-data'...\n")
# ['ais-data', 'requirements.txt', 'launch_ipykernel.py']

# %%
# %%time
# Get AIS data from date range (June)
start_date = datetime.fromisoformat("2022-01-01")
end_date = datetime.fromisoformat("2022-06-01")
df = af.get_ais(spark,start_date, end_date = end_date)

df.show()

# 16.1s for 1 week
# 19.3s for 1 month
# Out:
# +------------+---------+-------------------+-----------+-----------+-------+-----------+--------+---------------+----------------+-----------------+------------+------+-----+------------+---------+-----------------+----+-------+----+-----+---+-------+--------------------+---------------+------+-------------------+-------------------+----------------+---------------+-------------------+--------------------+---------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# |message_type|     mmsi|      dt_insert_utc|  longitude|   latitude|    imo|vessel_name|callsign|    vessel_type|vessel_type_code|vessel_type_cargo|vessel_class|length|width|flag_country|flag_code|      destination| eta|draught| sog|  cog|rot|heading|          nav_status|nav_status_code|source|         dt_pos_utc|      dt_static_utc|vessel_type_main|vessel_type_sub|               eeid|     source_filename|      H3index_0|    H3_int_index_0|    H3_int_index_1|    H3_int_index_2|    H3_int_index_3|    H3_int_index_4|    H3_int_index_5|    H3_int_index_6|    H3_int_index_7|    H3_int_index_8|    H3_int_index_9|   H3_int_index_10|   H3_int_index_11|   H3_int_index_12|   H3_int_index_13|   H3_int_index_14|   H3_int_index_15|
# +------------+---------+-------------------+-----------+-----------+-------+-----------+--------+---------------+----------------+-----------------+------------+------+-----+------------+---------+-----------------+----+-------+----+-----+---+-------+--------------------+---------------+------+-------------------+-------------------+----------------+---------------+-------------------+--------------------+---------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
#
    Service Ship|  Patrol Vessel|4761645918517774864|s3a://ungp-ais-da...|8001fffffffffff|576495936675512319|580968749977305087|585470700337233919|589974162525650943|594477753563086847|598981349969231871|603484948657078271|607988548217339903|612492147834224639|616995747459760127|621499347086999551|626002946714341375|630506546341710335|635010145969080383|639513745596450847|644017345223821337|
# |           1|259050000|2022-06-01 00:25:52|26.03606833|76.50530667|9312107| KV HARSTAD|    JWBR|Law Enforcement|              55|             null|           A|  83.0| 18.0|      Norway|      259|COASTGUARD PATROL|2460|    6.0| 9.9|  2.2|0.0|    1.0|Under Way Using E...|              0| S-AIS|2022-06-01 00:25:32|2022-05-31 23:47:56|    Service Ship|  Patrol Vessel|4761645918517774864|s3a://ungp-ais-da...|8001fffffffffff|576495936675512319|580968749977305087|585470700337233919|589974162525650943|594477753563086847|598981349969231871|603484949059731455|607988548670324735|612492148293500927|616995747919298559|621499347546472447|626002947173822463|630506546801189375|635010146428559423|639513746055929863|644017345683300353|
# +------------+---------+-------------------+-----------+-----------+-------+-----------+--------+---------------+----------------+-----------------+------------+------+-----+------------+---------+-----------------+----+-------+----+-----+---+-------+--------------------+---------------+------+-------------------+-------------------+----------------+---------------+-------------------+--------------------+---------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+------------------+
# only showing top 20 rows
#
# CPU times: user 16.1 ms, sys: 5.25 ms, total: 21.4 ms
# Wall time: 14.8 s

# %%
# Define polygon for vancouver port
vanPort = { "type": "Polygon", 
            "coordinates": [ 
                [ 
                    [-123.212426525887096, 49.274760228402968],
                    [-122.985548446858502, 49.251700411088592], 
                    [-122.988952264515504, 49.355219640768908],
                    [-123.214802962515606, 49.353944465477369],
                    [-123.212426525887096, 49.274760228402968]
                ]
            ]
          }

# %%
# %%time
# Filter by geography
df_van = af.apply_geo_filter(spark, df, vanPort)

df_van.count()

# Takes a few mins (5 mins 30s)
# Out:
# CPU times: user 55.5 ms, sys: 22.1 ms, total: 77.6 ms
# Wall time: 2min 51s
# 1145148

# %%
# %%time
pd.set_option('display.max_columns', 50)

# Try to convert it to pandas df
try:
    df_van = df_van.toPandas()
    display(df_van)
except:
    print("The dataframe was too large to convert to Pandas")
# Out:
#          message_type       mmsi       dt_insert_utc   longitude   latitude  \
# 0                   3  233217000 2022-06-01 02:00:21 -123.075215  49.306147
# 1                   3  233217000 2022-06-01 01:24:29 -123.075192  49.306133
# 2                  27  233217000 2022-06-01 00:49:34 -123.075000  49.305000
# 3                  27  233217000 2022-06-01 00:13:45 -123.075000  49.305000
# 4                  27  233217000 2022-06-01 01:01:14 -123.075000  49.305000
# ...               ...        ...                 ...         ...        ...
# 1145143            27  538005471 2022-06-18 00:13:16 -123.201667  49.295000
# 1145144            27  538005471 2022-06-18 00:04:20 -123.201667  49.295000
# 1145145            18  538071457 2022-06-18 00:06:33 -123.121123  49.269798
# 1145146            18  538071457 2022-06-18 01:44:58 -123.121750  49.269985
# 1145147            18  538071457 2022-06-18 01:59:53 -123.121665  49.269982
#
#                imo vessel_name callsign vessel_type  vessel_type_code  \
# 0        5070127.0     ST EVAL     GTJF       Other                90
# 1        5070127.0     ST EVAL     GTJF       Other                90
# 2        5070127.0     ST EVAL     GTJF       Other                90
# 3        5070127.0     ST EVAL     GTJF       Other                90
# 4        5070127.0     ST EVAL     GTJF       Other                90
# ...            ...         ...      ...         ...               ...
# 1145143  9520845.0   MADREDEUS    V7EH6       Cargo                70
# 1145144  9520845.0   MADREDEUS    V7EH6       Cargo                70
# 1145145        NaN   SY SHE-RA  V7A2718     Sailing                36
# 1145146        NaN   SY SHE-RA  V7A2718     Sailing                36
# 1145147        NaN   SY SHE-RA  V7A2718     Sailing                36
#
#         vessel_type_cargo vessel_class  length  width      flag_country  \
# 0                    None            A    40.0    6.0                UK
# 1                    None            A    40.0    6.0                UK
# 2                    None            A    40.0    6.0                UK
# 3                    None            A    40.0    6.0                UK
# 4                    None            A    40.0    6.0                UK
# ...                   ...          ...     ...    ...               ...
# 1145143              None            A   240.0   38.0  Marshall Islands
# 1145144              None            A   240.0   38.0  Marshall Islands
# 1145145              None            B    19.0    5.0  Marshall Islands
# 1145146              None            B    19.0    5.0  Marshall Islands
# 1145147              None            B    19.0    5.0  Marshall Islands
#
#          flag_code    destination       eta  draught  sog    cog  rot  \
# 0              233  FRIDAY HARBOR  10191830      3.9  0.1   29.6  0.0
# 1              233  FRIDAY HARBOR  10191830      3.9  0.0   29.6  0.0
# 2              233  FRIDAY HARBOR  10191830      3.9  0.0   29.0  0.0
# 3              233  FRIDAY HARBOR  10191830      3.9  0.0   28.0  0.0
# 4              233  FRIDAY HARBOR  10191830      3.9  0.0   29.0  0.0
# ...            ...            ...       ...      ...  ...    ...  ...
# 1145143        538   ROBERTS BANK   6131900      7.6  0.0  199.0  0.0
# 1145144        538   ROBERTS BANK   6131900      7.6  0.0  199.0  0.0
# 1145145        538           None      2460      0.0  0.0    0.0  0.0
# 1145146        538           None      2460      0.0  0.0    0.0  0.0
# 1145147        538           None      2460      0.0  0.2    0.0  0.0
#
#          heading nav_status  nav_status_code source          dt_pos_utc  \
# 0          214.0     Moored                5  T-AIS 2022-06-01 02:00:15
# 1          214.0     Moored                5  T-AIS 2022-06-01 01:24:25
# 2            0.0     Moored                5  S-AIS 2022-06-01 00:49:13
# 3            0.0     Moored                5  S-AIS 2022-06-01 00:13:12
# 4            0.0     Moored                5  T-AIS 2022-06-01 01:01:10
# ...          ...        ...              ...    ...                 ...
# 1145143      0.0  At Anchor                1  S-AIS 2022-06-18 00:12:56
# 1145144      0.0  At Anchor                1  S-AIS 2022-06-18 00:03:55
# 1145145    238.0    Unknown               16  T-AIS 2022-06-18 00:06:29
# 1145146    166.0    Unknown               16  T-AIS 2022-06-18 01:44:50
# 1145147    180.0    Unknown               16  T-AIS 2022-06-18 01:59:50
#
#               dt_static_utc vessel_type_main vessel_type_sub  \
# 0       2022-06-01 01:50:23             None            None
# 1       2022-06-01 01:14:21             None            None
# 2       2022-06-01 00:38:22             None            None
# 3       2022-06-01 00:02:23             None            None
# 4       2022-06-01 00:50:23             None            None
# ...                     ...              ...             ...
# 1145143 2022-06-18 00:05:30     Bulk Carrier            None
# 1145144 2022-06-17 23:53:26     Bulk Carrier            None
# 1145145 2022-06-17 23:44:34             None            None
# 1145146 2022-06-17 23:44:34             None            None
# 1145147 2022-06-17 23:44:34             None            None
#
#                         eeid  \
# 0        5041315703268219880
# 1        5041315703268219880
# 2        5041315703268219880
# 3        5041315703268219880
# 4        5041315703268219880
# ...                      ...
# 1145143  9150366668626677727
# 1145144  9150366668626677727
# 1145145  7017331702927348129
# 1145146  7017331702927348129
# 1145147  7017331702927348129
#
#                                            source_filename        H3index_0  \
# 0        s3a://ungp-ais-data-historical-backup/exact-ea...  8029fffffffffff
#
# 1145147  617712130166882303  622215729794187263  626719329421537279
#
#             H3_int_index_12     H3_int_index_13     H3_int_index_14  \
# 0        631222895988802047  635726495616172287  640230095243542775
# 1        631222895988802047  635726495616172095  640230095243542703
# 2        631222895988729343  635726495616099455  640230095243469903
# 3        631222895988729343  635726495616099455  640230095243469903
# 4        631222895988729343  635726495616099455  640230095243469903
# ...                     ...                 ...                 ...
# 1145143  631222928771062271  635726528398432639  640230128025803079
# 1145144  631222928771062271  635726528398432639  640230128025803079
# 1145145  631222929048753151  635726528676123455  640230128303493943
# 1145146  631222929048904703  635726528676274751  640230128303645223
# 1145147  631222929048904703  635726528676275135  640230128303645615
#
#             H3_int_index_15
# 0        644733694870913269
# 1        644733694870913197
# 2        644733694870840397
# 3        644733694870840397
# 4        644733694870840397
# ...                     ...
# 1145143  644733727653173569
# 1145144  644733727653173569
# 1145145  644733727930864432
# 1145146  644733727931015717
# 1145147  644733727931016110
#
# [1145148 rows x 49 columns]
# CPU times: user 2min 14s, sys: 2.06 s, total: 2min 16s
# Wall time: 8min 26s

# %%
print(df_van['dt_pos_utc'].min())
print(df_van['dt_pos_utc'].max())
# Out:
# 2022-05-31 23:59:44
# 2022-07-01 23:59:48

# %%
# Drop row on 2022-06-30
df_van = df_van["2022-06-01 00:00:01" <= df_van['dt_pos_utc']]
df_van = df_van[df_van['dt_pos_utc'] <= "2022-06-30 23:59:59"]
df_van.reset_index(drop=True)

print(df_van['dt_pos_utc'].min())
print(len(df_van.index))
# Out:
# 2022-06-01 00:00:01
# 1109688

# %%
# Split DF into smaller files and save them to csv
list_df = np.array_split(df_van, 10)

for i in range(len(list_df)):
    list_df[i].to_csv("./ais-data/Data/van_port_{}.csv".format(i), index=False)

# %%
# Change directory
os.chdir("./ais-data")
print(os.listdir())
# Out:
# ['.git', 'README.md', 'vancouver_port.ipynb']

# %%
# Git Config
std_out = subprocess.run(["git", "config", "--global", "user.email", '"dennishuynh3@gmail.com"'], capture_output=True, text=True)
print(std_out)
std_out = subprocess.run(["git", "config", "--global", "user.name", '"DennisH3"'], capture_output=True, text=True)
print(std_out)
# Out:
# CompletedProcess(args=['git', 'config', '--global', 'user.email', '"dennishuynh3@gmail.com"'], returncode=0, stdout='', stderr='')
# CompletedProcess(args=['git', 'config', '--global', 'user.name', '"DennisH3"'], returncode=0, stdout='', stderr='')

# %%
# Push data to repo
# os.system("git add .")
std_out = subprocess.run(["git", "add", "."], capture_output=True, text=True)
print(std_out)
# Out:
# CompletedProcess(args=['git', 'add', '.'], returncode=0, stdout='', stderr='')

# %%
# os.system('git commit -m "Upload data file"')
std_out = subprocess.run(["git", "commit", "-m", "Upload data"], capture_output=True, text=True)
print(std_out)
# Out:
# CompletedProcess(args=['git', 'commit', '-m', 'Upload data'], returncode=0, stdout='[main d254395] Upload data\n 10 files changed, 1109698 insertions(+)\n create mode 100644 van_port_0.csv\n create mode 100644 van_port_1.csv\n create mode 100644 van_port_2.csv\n create mode 100644 van_port_3.csv\n create mode 100644 van_port_4.csv\n create mode 100644 van_port_5.csv\n create mode 100644 van_port_6.csv\n create mode 100644 van_port_7.csv\n create mode 100644 van_port_8.csv\n create mode 100644 van_port_9.csv\n', stderr='')

# %%
# File of df is too large 700 MB, max limit is 100 MB
un = "DennisH3"
pw = getpass.getpass(prompt="Please enter PAT")
push = "git push --repo https://{}:{}@github.com/CSBP-CPSE/ais-data.git".format(un, pw)

std_out = subprocess.run([push], capture_output=True, text=True, shell=True).stderr
print(std_out)

# %%
# Get number of unique ships per day
# Use DT_POS_UTC column: Date and Time of Last Position AIS Message in UTC [YYYY-MM-DD HH24:MI:SS]
df_van.groupby(pd.Grouper(key="dt_pos_utc", axis=0, freq="1D"))['mmsi'].count().reset_index()

# %%
# Get number of unique ships per hour
df_van.groupby(pd.Grouper(key="dt_pos_utc", axis=0, freq="1H"))['mmsi'].count().reset_index()

# %%
# Check nav status of ships
df_van['nav_status'].unique()

# %%
# We want ships that are moored
df_van_moored = df_van[df_van['nav_status'] == 'Moored']

# Create a column for dt_pos_utc_hour and dt_pos_utc_day
df_van_moored['dt_pos_utc_date'] = df_van_moored['dt_pos_utc'].dt.date
df_van_moored['dt_pos_utc_hour'] = df_van_moored['dt_pos_utc'].dt.hour

# Drop duplicates based on mmsi and date and hour
df_moored_date = df_van_moored.drop_duplicates(subset=['mmsi', 'dt_pos_utc_date'], ignore_index=True)
df_moored_hour = df_van_moored.drop_duplicates(subset=['mmsi', 'dt_pos_utc_hour'], ignore_index=True)

# Get number of unique ships per day and hour
display(df_moored_date.groupby("dt_pos_utc_date")['mmsi'].count().reset_index())
display(df_moored_hour.groupby(["dt_pos_utc_date", "dt_pos_utc_hour"])['mmsi'].count().reset_index())

# %%
# Count of unique ships that arrived in port by date
# Count time spent in port per ship
port_stats = df_van.groupby(['mmsi','vessel_type']).agg({'mmsi':'count','dt_pos_utc':['min','max']}).reset_index()
port_stats.columns = ['mmsi','vessel_type','obs_count','dt_pos_utc_min','dt_pos_utc_max']
port_stats['arrival_date'] = port_stats.dt_pos_utc_min.dt.date
port_stats['time_in_port'] = port_stats.dt_pos_utc_max - port_stats.dt_pos_utc_min
port_stats['time_in_port_sec'] = port_stats['time_in_port'].dt.total_seconds()

# Display
port_stats

# Length of port_stats is the number of unique ships in specified area

# %%
# Count of unique ships that were moored in port by date
# Count time spent in port per ship
port_stats2 = df_van_moored.groupby(['mmsi','vessel_type']).agg({'mmsi':'count','dt_pos_utc':['min','max']}).reset_index()
port_stats2.columns = ['mmsi','vessel_type','obs_count','dt_pos_utc_min','dt_pos_utc_max']
port_stats2['arrival_date'] = port_stats2.dt_pos_utc_min.dt.date
port_stats2['time_in_port'] = port_stats2.dt_pos_utc_max - port_stats.dt_pos_utc_min
port_stats2['time_in_port_sec'] = port_stats2['time_in_port'].dt.total_seconds()

# Display
port_stats2
